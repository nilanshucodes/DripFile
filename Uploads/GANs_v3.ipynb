# %% [markdown]
# **Generative Adversarial Network for an MNIST Handwritten Digits From Scratch in Keras**

# %%
import tensorflow as tf

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %%
# loading the mnist dataset
from tensorflow.keras.datasets.mnist import load_data

# load the images into memory
(trainX, trainy), (testX, testy) = load_data()

# summarize the shape of the dataset
print('Train', trainX.shape, trainy.shape)
print('Test', testX.shape, testy.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Train (60000, 28, 28) (60000,)
# Test (10000, 28, 28) (10000,)

# %%
#plot of 25 images from the MNIST training dataset, arranged in a 5×5 square.

from tensorflow.keras.datasets.mnist import load_data
from matplotlib import pyplot
# load the images into memory
(trainX, trainy), (testX, testy) = load_data()
# plot images from the training dataset
for i in range(25):
	# define subplot
	pyplot.subplot(5, 5, 1 + i)
	# turn off axis
	pyplot.axis('off')
	# plot raw pixel data
	pyplot.imshow(trainX[i], cmap='gray_r')
pyplot.show()

# %% [markdown]
# **MNIST dataset to train the generator and the discriminator. The generator will generate Unique handwritten digits resembling the MNIST data.**

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
import tensorflow as tf

from IPython import display

# %%
(train_images, train_labels), (_, _) = tf.keras.datasets.mnist.load_data()

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5  # Normalize the images to [-1, 1]

# %%
BUFFER_SIZE = 60000
BATCH_SIZE = 256

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
# logs for the loss
# TensorBoard setup
import datetime
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
summary_writer = tf.summary.create_file_writer(log_dir)
train_step_counter = tf.Variable(0, dtype=tf.int64)

# %% [markdown]
# <h1>The Generator</h1>

# %% [markdown]
# The generator uses **tf.keras.layers.Conv2DTranspose (upsampling)** layers to produce an image from a random noise.

# %%
# outputs a single 28×28 grayscale image
# this generator takes a vector of size 100 and first reshape that into (7, 7, 128) vector then applied transpose
# convolution in combination with batch normalization.


def make_generator_model():
    model = tf.keras.Sequential()
    #7*7*256 is low resolution noise
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256)  # Note: None is the batch size
    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

   # upsample to 14x14
    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # upsample to 28x28
    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %% [markdown]
# <h1>Use the (as yet untrained) generator to create an image</h1>

# %%
# sample image generated by the the generator
generator = make_generator_model()

noise = tf.random.normal([1, 100]) #latent space
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# <h1>The Discriminator</h1>

# %% [markdown]
# **The discriminator is a CNN-based image classifier.**

# %%
# Input to discriminator = 28*28*1   grayscale image
# Output  binary prediction (image is real (class=1) or fake (class=0))
# no pooling layers
# single node in the output layer with the sigmoid activation function to predict whether the input sample is real or fake.
# Downsampling from 28×28 to 14×14, then to 7×7, before the model makes an output prediction
def make_discriminator_model():
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',input_shape=[28, 28, 1])) #2×2 stride to downsample
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same')) #downsampling  2×2 stride to downsample
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())  # classifier real (class=1) or fake (class=0))
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

# %% [markdown]
# **Use the (as yet untrained) discriminator to classify the generated images as real or fake. The model will be trained to output positive values for real images, and negative values for fake images**

# %%
discriminator = make_discriminator_model()
decision = discriminator(generated_image)
print (decision)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# tf.Tensor([[0.49966642]], shape=(1, 1), dtype=float32)

# %% [markdown]
# <h2>Define the loss and optimizers</h2>

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# <h2>Discriminator loss</h2>

# %% [markdown]
# **This method quantifies how well the discriminator is able to distinguish real images from fakes. It compares the discriminator's predictions on real images to an array of 1s, and the discriminator's predictions on fake (generated) images to an array of 0s.**

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %% [markdown]
# <h2>Generator loss</h2>

# %% [markdown]
# **The generator's loss quantifies how well it was able to trick the discriminator. Intuitively, if the generator is performing well, the discriminator will classify the fake images as real (or 1). Here, compare the discriminators decisions on the generated images to an array of 1s.**

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# <h2>The discriminator and the generator optimizers.</h2>

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# <h2>Save checkpoints</h2>

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# <h2>Define the training loop</h2>

# %%
EPOCHS = 100
noise_dim = 100
num_examples_to_generate = 16

# You will reuse this seed overtime (so it's easier)
# to visualize progress in the animated GIF)
seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %% [markdown]
# **The training loop begins with generator receiving a random seed as input. That seed is used to produce an image. The discriminator is then used to classify real images (drawn from the training set) and fakes images (produced by the generator). The loss is calculated for each of these models, and the gradients are used to update the generator and discriminator.**

# %%
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# %%
def train(dataset, epochs):
    step = 0  # global step counter for logging

    for epoch in range(epochs):
        start = time.time()

        for image_batch in dataset:
            # train_step now returns losses
            g_loss, d_loss = train_step(image_batch)

            # TensorBoard logging every 100 steps
            if step % 100 == 0:
                with summary_writer.as_default():
                    tf.summary.scalar('Generator loss', g_loss, step=step)
                    tf.summary.scalar('Discriminator loss', d_loss, step=step)

            step += 1

        # Produce images for the GIF as you go
        display.clear_output(wait=True)
        generate_and_save_images(generator,
                                 epoch + 1,
                                 seed)

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        print('Time for epoch {} is {} sec'.format(epoch + 1, time.time() - start))

    # Generate after the final epoch
    display.clear_output(wait=True)
    generate_and_save_images(generator,
                             epochs,
                             seed)

# %% [markdown]
# <h2>Generate and save images</h2>

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(4, 4))

  for i in range(predictions.shape[0]):
      plt.subplot(4, 4, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %% [markdown]
# <h1>Train the model</h1>

# %% [markdown]
# **Call the train() method defined above to train the generator and discriminator simultaneously. Note, training GANs can be tricky. It's important that the generator and discriminator do not overpower each other (e.g., that they train at a similar rate).**
#
# **At the beginning of the training, the generated images look like random noise. As training progresses, the generated digits will look increasingly real. After about 50 epochs, they resemble MNIST digits. This may take about one minute / epoch with the default settings on Colab.**

# %%
train(train_dataset, EPOCHS)
# Out:
# Time for epoch 10 is 11.985597133636475 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-31-2228458018.py in <cell line: 0>()
# ----> 1 train(train_dataset, EPOCHS)
#
# /tmp/ipython-input-29-3579287602.py in train(dataset, epochs)
#       4
#       5     for image_batch in dataset:
# ----> 6       train_step(image_batch)
#       7
#       8     # Produce images for the GIF as you go
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
# Display a single image using the epoch number
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
display_image(EPOCHS)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x400>

# %%
# !zip -r gan.zip /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2025.07.28/ (stored 0%)
#   adding: content/.config/logs/2025.07.28/13.43.38.841290.log (deflated 58%)
#   adding: content/.config/logs/2025.07.28/13.43.47.501739.log (deflated 86%)
#   adding: content/.config/logs/2025.07.28/13.43.17.935358.log (deflated 93%)
#   adding: content/.config/logs/2025.07.28/13.43.58.575036.log (deflated 56%)
#   adding: content/.config/logs/2025.07.28/13.43.48.733131.log (deflated 58%)
#   adding: content/.config/logs/2025.07.28/13.43.57.863217.log (deflated 57%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/image_at_epoch_0190.png (deflated 10%)
#   adding: content/image_at_epoch_0023.png (deflated 9%)
#   adding: content/image_at_epoch_0014.png (deflated 9%)
#   adding: content/image_at_epoch_0181.png (deflated 10%)
#   adding: content/image_at_epoch_0176.png (deflated 9%)
#   adding: content/image_at_epoch_0159.png (deflated 9%)
#   adding: content/image_at_epoch_0141.png (deflated 10%)
#   adding: content/image_at_epoch_0081.png (deflated 9%)
#   adding: content/image_at_epoch_0071.png (deflated 9%)
#   adding: content/image_at_epoch_0189.png (deflated 10%)
#   adding: content/image_at_epoch_0115.png (deflated 9%)
#   adding: content/image_at_epoch_0200.png (deflated 10%)
#   adding: content/image_at_epoch_0094.png (deflated 10%)
#   adding: content/image_at_epoch_0031.png (deflated 8%)
#   adding: content/image_at_epoch_0069.png (deflated 9%)
#   adding: content/image_at_epoch_0114.png (deflated 10%)
#   adding: content/image_at_epoch_0052.png (deflated 9%)
#   adding: content/training_checkpoints/ (stored 0%)
#   adding: content/training_checkpoints/ckpt-11.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-2.index (deflated 67%)
#   adding: content/training_checkpoints/checkpoint (deflated 38%)
#   adding: content/training_checkpoints/ckpt-9.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-9.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-6.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-10.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-12.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-5.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-3.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-10.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-4.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-8.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-11.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-6.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-1.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-4.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-3.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-12.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-5.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-7.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-1.data-00000-of-00001 (deflated 9%)
#   adding: content/training_checkpoints/ckpt-13.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-8.data-00000-of-00001 (deflated 8%)
#   adding: content/training_checkpoints/ckpt-7.index (deflated 67%)
#   adding: content/training_checkpoints/ckpt-2.data-00000-of-00001 (deflated 9%)
#   adding: content/training_checkpoints/ckpt-13.index (deflated 67%)
#   adding: content/image_at_epoch_0105.png (deflated 9%)
#   adding: content/image_at_epoch_0025.png (deflated 9%)
#   adding: content/image_at_epoch_0058.png (deflated 9%)
#   adding: content/image_at_epoch_0107.png (deflated 9%)
#   adding: content/image_at_epoch_0179.png (deflated 10%)
#   adding: content/image_at_epoch_0121.png (deflated 10%)
#   adding: content/image_at_epoch_0099.png (deflated 10%)
#   adding: content/image_at_epoch_0007.png (deflated 7%)
#   adding: content/image_at_epoch_0143.png (deflated 10%)
#   adding: content/image_at_epoch_0073.png (deflated 9%)
#   adding: content/image_at_epoch_0154.png (deflated 9%)
#   adding: content/image_at_epoch_0138.png (deflated 10%)
#   adding: content/image_at_epoch_0112.png (deflated 9%)
#   adding: content/image_at_epoch_0029.png (deflated 8%)
#   adding: content/image_at_epoch_0051.png (deflated 9%)
#   adding: content/image_at_epoch_0196.png (deflated 10%)
#   adding: content/image_at_epoch_0187.png (deflated 9%)
#   adding: content/image_at_epoch_0182.png (deflated 10%)
#   adding: content/image_at_epoch_0037.png (deflated 9%)
#   adding: content/image_at_epoch_0016.png (deflated 9%)
#   adding: content/image_at_epoch_0152.png (deflated 10%)
#   adding: content/image_at_epoch_0169.png (deflated 9%)
#   adding: content/image_at_epoch_0122.png (deflated 9%)
#   adding: content/image_at_epoch_0104.png (deflated 9%)
#   adding: content/image_at_epoch_0091.png (deflated 9%)
#   adding: content/image_at_epoch_0066.png (deflated 9%)
#   adding: content/image_at_epoch_0140.png (deflated 10%)
#   adding: content/image_at_epoch_0048.png (deflated 9%)
#   adding: content/image_at_epoch_0002.png (deflated 6%)
#   adding: content/image_at_epoch_0013.png (deflated 9%)
#   adding: content/image_at_epoch_0036.png (deflated 9%)
#   adding: content/image_at_epoch_0090.png (deflated 9%)
#   adding: content/image_at_epoch_0059.png (deflated 10%)
#   adding: content/image_at_epoch_0039.png (deflated 9%)
#   adding: content/image_at_epoch_0153.png (deflated 9%)
#   adding: content/image_at_epoch_0165.png (deflated 9%)
#   adding: content/image_at_epoch_0132.png (deflated 9%)
#   adding: content/image_at_epoch_0020.png (deflated 10%)
#   adding: content/image_at_epoch_0177.png (deflated 10%)
#   adding: content/image_at_epoch_0197.png (deflated 10%)
#   adding: content/image_at_epoch_0042.png (deflated 9%)
#   adding: content/image_at_epoch_0024.png (deflated 8%)
#   adding: content/image_at_epoch_0038.png (deflated 9%)
#   adding: content/image_at_epoch_0156.png (deflated 10%)
#   adding: content/image_at_epoch_0075.png (deflated 10%)
#   adding: content/image_at_epoch_0050.png (deflated 9%)
#   adding: content/image_at_epoch_0098.png (deflated 10%)
#   adding: content/image_at_epoch_0144.png (deflated 9%)
#   adding: content/image_at_epoch_0045.png (deflated 9%)
#   adding: content/image_at_epoch_0106.png (deflated 9%)
#   adding: content/image_at_epoch_0192.png (deflated 10%)
#   adding: content/image_at_epoch_0080.png (deflated 10%)
#   adding: content/image_at_epoch_0005.png (deflated 9%)
#   adding: content/image_at_epoch_0117.png (deflated 9%)
#   adding: content/image_at_epoch_0061.png (deflated 9%)
#   adding: content/image_at_epoch_0188.png (deflated 10%)
#   adding: content/image_at_epoch_0027.png (deflated 8%)
#   adding: content/image_at_epoch_0021.png (deflated 9%)
#   adding: content/image_at_epoch_0198.png (deflated 10%)
#   adding: content/image_at_epoch_0183.png (deflated 9%)
#   adding: content/image_at_epoch_0170.png (deflated 9%)
#   adding: content/image_at_epoch_0062.png (deflated 9%)
#   adding: content/image_at_epoch_0163.png (deflated 10%)
#   adding: content/image_at_epoch_0009.png (deflated 10%)
#   adding: content/image_at_epoch_0022.png (deflated 9%)
#   adding: content/image_at_epoch_0199.png (deflated 9%)
#   adding: content/image_at_epoch_0047.png (deflated 9%)
#   adding: content/image_at_epoch_0011.png (deflated 10%)
#   adding: content/image_at_epoch_0084.png (deflated 9%)
#   adding: content/image_at_epoch_0067.png (deflated 9%)
#   adding: content/image_at_epoch_0194.png (deflated 10%)
#   adding: content/image_at_epoch_0164.png (deflated 10%)
#   adding: content/image_at_epoch_0064.png (deflated 9%)
#   adding: content/image_at_epoch_0040.png (deflated 9%)
#   adding: content/image_at_epoch_0103.png (deflated 9%)
#   adding: content/image_at_epoch_0136.png (deflated 9%)
#   adding: content/image_at_epoch_0134.png (deflated 10%)
#   adding: content/image_at_epoch_0108.png (deflated 9%)
#   adding: content/image_at_epoch_0089.png (deflated 9%)
#   adding: content/image_at_epoch_0166.png (deflated 9%)
#   adding: content/image_at_epoch_0193.png (deflated 10%)
#   adding: content/image_at_epoch_0088.png (deflated 9%)
#   adding: content/image_at_epoch_0172.png (deflated 9%)
#   adding: content/image_at_epoch_0116.png (deflated 9%)
#   adding: content/image_at_epoch_0043.png (deflated 9%)
#   adding: content/image_at_epoch_0010.png (deflated 8%)
#   adding: content/image_at_epoch_0035.png (deflated 9%)
#   adding: content/image_at_epoch_0142.png (deflated 9%)
#   adding: content/image_at_epoch_0135.png (deflated 10%)
#   adding: content/image_at_epoch_0146.png (deflated 10%)
#   adding: content/image_at_epoch_0161.png (deflated 10%)
#   adding: content/image_at_epoch_0113.png (deflated 9%)
#   adding: content/image_at_epoch_0124.png (deflated 9%)
#   adding: content/image_at_epoch_0032.png (deflated 9%)
#   adding: content/image_at_epoch_0063.png (deflated 9%)
#   adding: content/image_at_epoch_0157.png (deflated 10%)
#   adding: content/image_at_epoch_0028.png (deflated 8%)
#   adding: content/image_at_epoch_0087.png (deflated 10%)
#   adding: content/image_at_epoch_0151.png (deflated 10%)
#   adding: content/image_at_epoch_0137.png (deflated 10%)
#   adding: content/image_at_epoch_0195.png (deflated 10%)
#   adding: content/image_at_epoch_0150.png (deflated 10%)
#   adding: content/image_at_epoch_0125.png (deflated 10%)
#   adding: content/image_at_epoch_0100.png (deflated 10%)
#   adding: content/image_at_epoch_0126.png (deflated 10%)
#   adding: content/image_at_epoch_0008.png (deflated 8%)
#   adding: content/image_at_epoch_0155.png (deflated 10%)
#   adding: content/image_at_epoch_0160.png (deflated 10%)
#   adding: content/image_at_epoch_0109.png (deflated 9%)
#   adding: content/image_at_epoch_0178.png (deflated 10%)
#   adding: content/image_at_epoch_0072.png (deflated 9%)
#   adding: content/image_at_epoch_0019.png (deflated 10%)
#   adding: content/image_at_epoch_0173.png (deflated 10%)
#   adding: content/image_at_epoch_0133.png (deflated 9%)
#   adding: content/image_at_epoch_0131.png (deflated 10%)
#   adding: content/image_at_epoch_0093.png (deflated 10%)
#   adding: content/image_at_epoch_0086.png (deflated 9%)
#   adding: content/image_at_epoch_0123.png (deflated 9%)
#   adding: content/image_at_epoch_0077.png (deflated 9%)
#   adding: content/image_at_epoch_0057.png (deflated 10%)
#   adding: content/image_at_epoch_0096.png (deflated 10%)
#   adding: content/image_at_epoch_0102.png (deflated 9%)
#   adding: content/image_at_epoch_0145.png (deflated 10%)
#   adding: content/image_at_epoch_0012.png (deflated 9%)
#   adding: content/image_at_epoch_0129.png (deflated 10%)
#   adding: content/image_at_epoch_0060.png (deflated 9%)
#   adding: content/image_at_epoch_0101.png (deflated 9%)
#   adding: content/image_at_epoch_0191.png (deflated 10%)
#   adding: content/image_at_epoch_0054.png (deflated 9%)
#   adding: content/image_at_epoch_0120.png (deflated 10%)
#   adding: content/image_at_epoch_0111.png (deflated 10%)
#   adding: content/image_at_epoch_0092.png (deflated 10%)
#   adding: content/image_at_epoch_0030.png (deflated 8%)
#   adding: content/image_at_epoch_0119.png (deflated 9%)
#   adding: content/image_at_epoch_0017.png (deflated 11%)
#   adding: content/image_at_epoch_0056.png (deflated 9%)
#   adding: content/image_at_epoch_0034.png (deflated 8%)
#   adding: content/image_at_epoch_0003.png (deflated 8%)
#   adding: content/image_at_epoch_0068.png (deflated 10%)
#   adding: content/image_at_epoch_0180.png (deflated 10%)
#   adding: content/image_at_epoch_0049.png (deflated 9%)
#   adding: content/image_at_epoch_0110.png (deflated 11%)
#   adding: content/image_at_epoch_0128.png (deflated 10%)
#   adding: content/image_at_epoch_0065.png (deflated 10%)
#   adding: content/image_at_epoch_0149.png (deflated 10%)
#   adding: content/image_at_epoch_0174.png (deflated 9%)
#   adding: content/image_at_epoch_0184.png (deflated 10%)
#   adding: content/image_at_epoch_0004.png (deflated 10%)
#   adding: content/image_at_epoch_0085.png (deflated 9%)
#   adding: content/image_at_epoch_0139.png (deflated 10%)
#   adding: content/image_at_epoch_0074.png (deflated 9%)
#   adding: content/image_at_epoch_0041.png (deflated 8%)
#   adding: content/image_at_epoch_0130.png (deflated 9%)
#   adding: content/image_at_epoch_0185.png (deflated 10%)
#   adding: content/image_at_epoch_0070.png (deflated 10%)
#   adding: content/image_at_epoch_0053.png (deflated 10%)
#   adding: content/image_at_epoch_0097.png (deflated 10%)
#   adding: content/image_at_epoch_0118.png (deflated 9%)
#   adding: content/image_at_epoch_0147.png (deflated 9%)
#   adding: content/image_at_epoch_0015.png (deflated 8%)
#   adding: content/image_at_epoch_0095.png (deflated 10%)
#   adding: content/image_at_epoch_0026.png (deflated 8%)
#   adding: content/image_at_epoch_0168.png (deflated 10%)
#   adding: content/image_at_epoch_0018.png (deflated 10%)
#   adding: content/image_at_epoch_0001.png (deflated 6%)
#   adding: content/image_at_epoch_0044.png (deflated 9%)
#   adding: content/image_at_epoch_0033.png (deflated 9%)
#   adding: content/image_at_epoch_0083.png (deflated 9%)
#   adding: content/image_at_epoch_0162.png (deflated 10%)
#   adding: content/image_at_epoch_0046.png (deflated 9%)
#   adding: content/image_at_epoch_0078.png (deflated 9%)
#   adding: content/image_at_epoch_0006.png (deflated 8%)
#   adding: content/image_at_epoch_0127.png (deflated 10%)
#   adding: content/image_at_epoch_0175.png (deflated 10%)
#   adding: content/image_at_epoch_0076.png (deflated 9%)
#   adding: content/image_at_epoch_0148.png (deflated 10%)
#   adding: content/image_at_epoch_0167.png (deflated 9%)
#   adding: content/image_at_epoch_0186.png (deflated 10%)
#   adding: content/image_at_epoch_0158.png (deflated 10%)
#   adding: content/image_at_epoch_0079.png (deflated 10%)
#   adding: content/image_at_epoch_0171.png (deflated 9%)
#   adding: content/image_at_epoch_0082.png (deflated 10%)
#   adding: content/image_at_epoch_0055.png (deflated 9%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)

# %%
# !zip images.zip /content/*.png
# Out:
#   adding: content/image_at_epoch_0001.png (deflated 6%)
#   adding: content/image_at_epoch_0002.png (deflated 6%)
#   adding: content/image_at_epoch_0003.png (deflated 8%)
#   adding: content/image_at_epoch_0004.png (deflated 10%)
#   adding: content/image_at_epoch_0005.png (deflated 9%)
#   adding: content/image_at_epoch_0006.png (deflated 8%)
#   adding: content/image_at_epoch_0007.png (deflated 7%)
#   adding: content/image_at_epoch_0008.png (deflated 8%)
#   adding: content/image_at_epoch_0009.png (deflated 10%)
#   adding: content/image_at_epoch_0010.png (deflated 8%)
#   adding: content/image_at_epoch_0011.png (deflated 10%)
#   adding: content/image_at_epoch_0012.png (deflated 9%)
#   adding: content/image_at_epoch_0013.png (deflated 9%)
#   adding: content/image_at_epoch_0014.png (deflated 9%)
#   adding: content/image_at_epoch_0015.png (deflated 8%)
#   adding: content/image_at_epoch_0016.png (deflated 9%)
#   adding: content/image_at_epoch_0017.png (deflated 11%)
#   adding: content/image_at_epoch_0018.png (deflated 10%)
#   adding: content/image_at_epoch_0019.png (deflated 10%)
#   adding: content/image_at_epoch_0020.png (deflated 10%)
#   adding: content/image_at_epoch_0021.png (deflated 9%)
#   adding: content/image_at_epoch_0022.png (deflated 9%)
#   adding: content/image_at_epoch_0023.png (deflated 9%)
#   adding: content/image_at_epoch_0024.png (deflated 8%)
#   adding: content/image_at_epoch_0025.png (deflated 9%)
#   adding: content/image_at_epoch_0026.png (deflated 8%)
#   adding: content/image_at_epoch_0027.png (deflated 8%)
#   adding: content/image_at_epoch_0028.png (deflated 8%)
#   adding: content/image_at_epoch_0029.png (deflated 8%)
#   adding: content/image_at_epoch_0030.png (deflated 8%)
#   adding: content/image_at_epoch_0031.png (deflated 8%)
#   adding: content/image_at_epoch_0032.png (deflated 9%)
#   adding: content/image_at_epoch_0033.png (deflated 9%)
#   adding: content/image_at_epoch_0034.png (deflated 8%)
#   adding: content/image_at_epoch_0035.png (deflated 9%)
#   adding: content/image_at_epoch_0036.png (deflated 9%)
#   adding: content/image_at_epoch_0037.png (deflated 9%)
#   adding: content/image_at_epoch_0038.png (deflated 9%)
#   adding: content/image_at_epoch_0039.png (deflated 9%)
#   adding: content/image_at_epoch_0040.png (deflated 9%)
#   adding: content/image_at_epoch_0041.png (deflated 8%)
#   adding: content/image_at_epoch_0042.png (deflated 9%)
#   adding: content/image_at_epoch_0043.png (deflated 9%)
#   adding: content/image_at_epoch_0044.png (deflated 9%)
#   adding: content/image_at_epoch_0045.png (deflated 9%)
#   adding: content/image_at_epoch_0046.png (deflated 9%)
#   adding: content/image_at_epoch_0047.png (deflated 9%)
#   adding: content/image_at_epoch_0048.png (deflated 9%)
#   adding: content/image_at_epoch_0049.png (deflated 9%)
#   adding: content/image_at_epoch_0050.png (deflated 9%)
#   adding: content/image_at_epoch_0051.png (deflated 9%)
#   adding: content/image_at_epoch_0052.png (deflated 9%)
#   adding: content/image_at_epoch_0053.png (deflated 10%)
#   adding: content/image_at_epoch_0054.png (deflated 9%)
#   adding: content/image_at_epoch_0055.png (deflated 9%)
#   adding: content/image_at_epoch_0056.png (deflated 9%)
#   adding: content/image_at_epoch_0057.png (deflated 10%)
#   adding: content/image_at_epoch_0058.png (deflated 9%)
#   adding: content/image_at_epoch_0059.png (deflated 10%)
#   adding: content/image_at_epoch_0060.png (deflated 9%)
#   adding: content/image_at_epoch_0061.png (deflated 9%)
#   adding: content/image_at_epoch_0062.png (deflated 9%)
#   adding: content/image_at_epoch_0063.png (deflated 9%)
#   adding: content/image_at_epoch_0064.png (deflated 9%)
#   adding: content/image_at_epoch_0065.png (deflated 10%)
#   adding: content/image_at_epoch_0066.png (deflated 9%)
#   adding: content/image_at_epoch_0067.png (deflated 9%)
#   adding: content/image_at_epoch_0068.png (deflated 10%)
#   adding: content/image_at_epoch_0069.png (deflated 9%)
#   adding: content/image_at_epoch_0070.png (deflated 10%)
#   adding: content/image_at_epoch_0071.png (deflated 9%)
#   adding: content/image_at_epoch_0072.png (deflated 9%)
#   adding: content/image_at_epoch_0073.png (deflated 9%)
#   adding: content/image_at_epoch_0074.png (deflated 9%)
#   adding: content/image_at_epoch_0075.png (deflated 10%)
#   adding: content/image_at_epoch_0076.png (deflated 9%)
#   adding: content/image_at_epoch_0077.png (deflated 9%)
#   adding: content/image_at_epoch_0078.png (deflated 9%)
#   adding: content/image_at_epoch_0079.png (deflated 10%)
#   adding: content/image_at_epoch_0080.png (deflated 10%)
#   adding: content/image_at_epoch_0081.png (deflated 9%)
#   adding: content/image_at_epoch_0082.png (deflated 10%)
#   adding: content/image_at_epoch_0083.png (deflated 9%)
#   adding: content/image_at_epoch_0084.png (deflated 9%)
#   adding: content/image_at_epoch_0085.png (deflated 9%)
#   adding: content/image_at_epoch_0086.png (deflated 9%)
#   adding: content/image_at_epoch_0087.png (deflated 10%)
#   adding: content/image_at_epoch_0088.png (deflated 9%)
#   adding: content/image_at_epoch_0089.png (deflated 9%)
#   adding: content/image_at_epoch_0090.png (deflated 9%)
#   adding: content/image_at_epoch_0091.png (deflated 9%)
#   adding: content/image_at_epoch_0092.png (deflated 10%)
#   adding: content/image_at_epoch_0093.png (deflated 10%)
#   adding: content/image_at_epoch_0094.png (deflated 10%)
#   adding: content/image_at_epoch_0095.png (deflated 10%)
#   adding: content/image_at_epoch_0096.png (deflated 10%)
#   adding: content/image_at_epoch_0097.png (deflated 10%)
#   adding: content/image_at_epoch_0098.png (deflated 10%)
#   adding: content/image_at_epoch_0099.png (deflated 10%)
#   adding: content/image_at_epoch_0100.png (deflated 10%)
#   adding: content/image_at_epoch_0101.png (deflated 9%)
#   adding: content/image_at_epoch_0102.png (deflated 9%)
#   adding: content/image_at_epoch_0103.png (deflated 9%)
#   adding: content/image_at_epoch_0104.png (deflated 9%)
#   adding: content/image_at_epoch_0105.png (deflated 9%)
#   adding: content/image_at_epoch_0106.png (deflated 9%)
#   adding: content/image_at_epoch_0107.png (deflated 9%)
#   adding: content/image_at_epoch_0108.png (deflated 9%)
#   adding: content/image_at_epoch_0109.png (deflated 9%)
#   adding: content/image_at_epoch_0110.png (deflated 11%)
#   adding: content/image_at_epoch_0111.png (deflated 10%)
#   adding: content/image_at_epoch_0112.png (deflated 9%)
#   adding: content/image_at_epoch_0113.png (deflated 9%)
#   adding: content/image_at_epoch_0114.png (deflated 10%)
#   adding: content/image_at_epoch_0115.png (deflated 9%)
#   adding: content/image_at_epoch_0116.png (deflated 9%)
#   adding: content/image_at_epoch_0117.png (deflated 9%)
#   adding: content/image_at_epoch_0118.png (deflated 9%)
#   adding: content/image_at_epoch_0119.png (deflated 9%)
#   adding: content/image_at_epoch_0120.png (deflated 10%)
#   adding: content/image_at_epoch_0121.png (deflated 10%)
#   adding: content/image_at_epoch_0122.png (deflated 9%)
#   adding: content/image_at_epoch_0123.png (deflated 9%)
#   adding: content/image_at_epoch_0124.png (deflated 9%)
#   adding: content/image_at_epoch_0125.png (deflated 10%)
#   adding: content/image_at_epoch_0126.png (deflated 10%)
#   adding: content/image_at_epoch_0127.png (deflated 10%)
#   adding: content/image_at_epoch_0128.png (deflated 10%)
#   adding: content/image_at_epoch_0129.png (deflated 10%)
#   adding: content/image_at_epoch_0130.png (deflated 9%)
#   adding: content/image_at_epoch_0131.png (deflated 10%)
#   adding: content/image_at_epoch_0132.png (deflated 9%)
#   adding: content/image_at_epoch_0133.png (deflated 9%)
#   adding: content/image_at_epoch_0134.png (deflated 10%)
#   adding: content/image_at_epoch_0135.png (deflated 10%)
#   adding: content/image_at_epoch_0136.png (deflated 9%)
#   adding: content/image_at_epoch_0137.png (deflated 10%)
#   adding: content/image_at_epoch_0138.png (deflated 10%)
#   adding: content/image_at_epoch_0139.png (deflated 10%)
#   adding: content/image_at_epoch_0140.png (deflated 10%)
#   adding: content/image_at_epoch_0141.png (deflated 10%)
#   adding: content/image_at_epoch_0142.png (deflated 9%)
#   adding: content/image_at_epoch_0143.png (deflated 10%)
#   adding: content/image_at_epoch_0144.png (deflated 9%)
#   adding: content/image_at_epoch_0145.png (deflated 10%)
#   adding: content/image_at_epoch_0146.png (deflated 10%)
#   adding: content/image_at_epoch_0147.png (deflated 9%)
#   adding: content/image_at_epoch_0148.png (deflated 10%)
#   adding: content/image_at_epoch_0149.png (deflated 10%)
#   adding: content/image_at_epoch_0150.png (deflated 10%)
#   adding: content/image_at_epoch_0151.png (deflated 10%)
#   adding: content/image_at_epoch_0152.png (deflated 10%)
#   adding: content/image_at_epoch_0153.png (deflated 9%)
#   adding: content/image_at_epoch_0154.png (deflated 9%)
#   adding: content/image_at_epoch_0155.png (deflated 10%)
#   adding: content/image_at_epoch_0156.png (deflated 10%)
#   adding: content/image_at_epoch_0157.png (deflated 10%)
#   adding: content/image_at_epoch_0158.png (deflated 10%)
#   adding: content/image_at_epoch_0159.png (deflated 9%)
#   adding: content/image_at_epoch_0160.png (deflated 10%)
#   adding: content/image_at_epoch_0161.png (deflated 10%)
#   adding: content/image_at_epoch_0162.png (deflated 10%)
#   adding: content/image_at_epoch_0163.png (deflated 10%)
#   adding: content/image_at_epoch_0164.png (deflated 10%)
#   adding: content/image_at_epoch_0165.png (deflated 9%)
#   adding: content/image_at_epoch_0166.png (deflated 9%)
#   adding: content/image_at_epoch_0167.png (deflated 9%)
#   adding: content/image_at_epoch_0168.png (deflated 10%)
#   adding: content/image_at_epoch_0169.png (deflated 9%)
#   adding: content/image_at_epoch_0170.png (deflated 9%)
#   adding: content/image_at_epoch_0171.png (deflated 9%)
#   adding: content/image_at_epoch_0172.png (deflated 9%)
#   adding: content/image_at_epoch_0173.png (deflated 10%)
#   adding: content/image_at_epoch_0174.png (deflated 9%)
#   adding: content/image_at_epoch_0175.png (deflated 10%)
#   adding: content/image_at_epoch_0176.png (deflated 9%)
#   adding: content/image_at_epoch_0177.png (deflated 10%)
#   adding: content/image_at_epoch_0178.png (deflated 10%)
#   adding: content/image_at_epoch_0179.png (deflated 10%)
#   adding: content/image_at_epoch_0180.png (deflated 10%)
#   adding: content/image_at_epoch_0181.png (deflated 10%)
#   adding: content/image_at_epoch_0182.png (deflated 10%)
#   adding: content/image_at_epoch_0183.png (deflated 9%)
#   adding: content/image_at_epoch_0184.png (deflated 10%)
#   adding: content/image_at_epoch_0185.png (deflated 10%)
#   adding: content/image_at_epoch_0186.png (deflated 10%)
#   adding: content/image_at_epoch_0187.png (deflated 9%)
#   adding: content/image_at_epoch_0188.png (deflated 10%)
#   adding: content/image_at_epoch_0189.png (deflated 10%)
#   adding: content/image_at_epoch_0190.png (deflated 10%)
#   adding: content/image_at_epoch_0191.png (deflated 10%)
#   adding: content/image_at_epoch_0192.png (deflated 10%)
#   adding: content/image_at_epoch_0193.png (deflated 10%)
#   adding: content/image_at_epoch_0194.png (deflated 10%)
#   adding: content/image_at_epoch_0195.png (deflated 10%)
#   adding: content/image_at_epoch_0196.png (deflated 10%)
#   adding: content/image_at_epoch_0197.png (deflated 10%)
#   adding: content/image_at_epoch_0198.png (deflated 10%)
#   adding: content/image_at_epoch_0199.png (deflated 9%)
#   adding: content/image_at_epoch_0200.png (deflated 10%)

# %%
# Save after all epochs
generator.save("/content/generator_model.keras")
discriminator.save("/content/discriminator_model.keras")
